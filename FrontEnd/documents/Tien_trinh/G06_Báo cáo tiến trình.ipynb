# %% [markdown]
# # Báo cáo tiến trình Project
# Lớp TTNT-147729, Nhóm G06

# %% [markdown]
# ### Thành viên
# - Vũ Đức Mạnh - 20215282
# - Lê Phúc Hưng - 20215276
# - Phạm Đức Dũng - 20215265
# - Trần Trung Nghĩa - 20213581
# - Đàm Minh Hải - 20215272
#
# ---

# %% [markdown]
# ### Mục Lục
# [I. Giới thiệu dự án](#i-mở-đầu)
# - [1. Lý do chọn đề tài](#ly-do)
# - [2. Mục đích của đề tài](#muc-dich)
# - [3. Phạm vi của đề tài](#pham-vi)
#
# [II. Khảo sát bài toán](#ii-Khaosat)
# - [1. Tóm tắt yêu cầu](#Yeucau)
# - [2. Khảo sát chung về cách xây dựng bài toán](#Khaosatchung)
#     - [2.1. Các mô hình thuật toán](#mo-hing-thuat-toan)
#     - [2.2. Các bước tiến hành](#cac-buoc-tien-hanh)
# - [3. Mô tả nghiệp vụ](#Nghiepvu)
#
# [III. Phương pháp giải quyết bài toán](#iii-phuongphap)
# - [1. Các mô hinhg Machine learning](#Machine-learning)
# - [2. Lọc cộng tác (Collaborative Filtering)](#loc-cong-tac)
# - [3. Xử dụng ngôn ngữ tự nhiên (NLP)](#NLP)
# - [4. Mô hình âm thanh](#mo-hinh-am-thanh)
# - [5. Áp dụng lọc cộng tác](ap-dung-loc-cong-tac)
#
# [IV. Kết quả ](#Ketqua)
#
# [V. Khó khăn cần khắc phục](#Khokhan)
#
# ---

# %% [markdown]
# <a name="Modau"></a>
#
# ## I. Giới thiệu dự án
#
# ### 1. Lý do chọn đề tài
# - Âm nhạc đóng vai trò quan trọng trong cuộc sống và công việc. Nó không chỉ là một phương tiện giải trí mà còn làm tăng cường tinh thần, giảm căng thẳng và kích thích sự sáng tạo.  m nhạc cũng là công cụ giao tiếp mạnh mẽ, giúp kết nối con người và truyền tải các giá trị văn hóa. Trong công việc, âm nhạc được sử dụng để tạo môi trường làm việc tích cực, thúc đẩy hiệu suất và sự sáng tạo. Nó có thể được áp dụng trong nhiều lĩnh vực như giáo dục, marketing, y tế và công nghệ để tạo ra trải nghiệm tốt hơn cho người sử dụng và khách hàng. Đồng thời, việc học và thực hành âm nhạc cũng giúp phát triển nhiều kỹ năng quan trọng như kỹ năng ngôn ngữ, tư duy logic và kỹ năng xã hội.
# - Để phát triển hơn những ưu điểm của âm nhạc, việc nghe đúng loại nhạc là một điều đóng vai trò tiên quyết. Mà trong thời kì hiện nay, kho tàng âm nhạc đã trở nên quá đồ sộ, chúng ta không có thời gian để nghe tất cả các bài nhạc, và chọn ra cho mình những bản nhạc phù hợp. Hiểu được điều này, bọn em quyết định chọn đề tài “Xây dựng hệ thống gợi ý dành cho người nghe nhạc trên ứng dụng Spotify”. Qua đề tài này, chúng em muốn xây dựng được một hệ thống sử dụng mô hình AI để hỗ trợ người dùng ứng dụng spotify trong việc lựa chọn và nghe nhạc. Chúng em rất mong kết quả của đề tài này có thể là một sản phẩm có ích với mọi người.
#
# ### 2. Mục đích của đề tài
# - Mục tiêu của đề tài "Xây dựng hệ thống gợi ý dành cho người nghe nhạc trên ứng dụng Spotify" là tạo ra một hệ thống gợi ý nhạc thông minh và hiệu quả nhằm cải thiện trải nghiệm người dùng trên ứng dụng Spotify nói chung và trong việc nghe nhạc nói riêng. Đây là một bước quan trọng trong việc tối ưu hóa dịch vụ nghe nhạc trực tuyến.
# Mục tiêu cụ thể bao gồm:
#     - Phát triển một thuật toán gợi ý thông minh dựa trên dữ liệu người dùng như lịch sử nghe nhạc, sở thích, phản hồi của họ với trợ lý ảo.
#     - Tối ưu hóa quy trình phân tích và xử lý dữ liệu để cung cấp gợi ý chính xác và đa dạng.
#     - Tích hợp các yếu tố như thị trường âm nhạc, xu hướng mới và thông tin về nghệ sĩ để cung cấp gợi ý đa chiều và hấp dẫn.
#     - Tạo ra một giao diện người dùng thân thiện và dễ sử dụng, cho phép người dùng tùy chỉnh và tương tác với các gợi ý theo ý muốn của họ.
#     - Đánh giá và cải tiến liên tục hệ thống dựa trên phản hồi từ người dùng và dữ liệu sử dụng.
#
# ### 3. Phạm vi của đề tài
# Với đề tài này, để có thể làm việc một cách hiệu quả, chúng em xin phép đặt ra phạm vi cho các phần nhiệm vụ chính như sau:
# - Thu thập và xử lý dữ liệu: Phạm vi này bao gồm việc thu thập dữ liệu về lịch sử nghe nhạc, thông tin người dùng, các yếu tố khác liên quan đến sở thích âm nhạc của ngưỡi dùng; dữ liệu về các bài nhạc, các xu hướng nghe nhạc. Sau đó, dữ liệu này được xử lý, làm tiền đề cho việc xây dựng mô hình AI và huấn luyện mô hình AI.
# - Xây dựng và huấn luyện mô hình AI: Phạm vi này tập trung vào việc phát triển các thuật toán học máy để dự đoán sở thích của người dùng và gợi ý cho họ các bài hát, album hoặc playlist phù hợp.
# - Tích hợp thông tin về âm nhạc: Phạm vi này bao gồm việc tích hợp thông tin về thị trường âm nhạc, xu hướng mới và thông tin về nghệ sĩ vào quá trình gợi ý để cung cấp cho người dùng các gợi ý đa dạng và phong phú.
# - Phát triển giao diện người dùng: Phạm vi này liên quan đến việc thiết kế và phát triển giao diện người dùng trực quan và dễ sử dụng để người dùng có thể tương tác và tùy chỉnh các gợi ý theo ý muốn của họ.
# - Đánh giá và cải tiến: Phạm vi này bao gồm việc đánh giá hiệu suất của hệ thống gợi ý thông qua các phản hồi từ người dùng và dữ liệu sử dụng, sau đó cải tiến hệ thống để tối ưu hóa trải nghiệm người dùng.
#
# -> Trên đây là những phạm vi chúng em đã đặt ra để quá trình thực hiện dự án có thể diễn ra một cách ổn định. Chúng em cũng mong răng với phạm vi này, chúng em có thể tạo ra một sản phẩm chất lượng

# %% [markdown]
# ## II. Khảo sát bài toán
#
# ### 1. Tóm tắt yêu cầu
# - Mô phỏng, xây dựng các thuật toán trí tuệ nhân tạo để tích hợp vào ứng dụng phát nhạc trực tuyến, giúp cá nhân hóa danh sách phát của người dùng
# - Có thể xây dựng một, hoặc sử dụng nhiều mô hình thuật toán. Sau khi xây dựng các thuật toán yêu cầu phải so sánh độ hiệu quả để tìm ra thuật toán phù hợp
# - Áp dụng vào chương trình tìm kiếm của ứng dụng đó sao cho hệ thống có thể gợi ý các bài hát phù hợp với từng người dùng, tùy vào lịch sử nghe và các nghệ sĩ người dùng yêu thích
#
# ### 2. Khảo sát chung về cách xây dựng bài toán
#
# #### 2.1. Các mô hình thuật toán
# - Một số tài liệu tham khảo được sử dụng trong vấn đề xây dựng mô hình giải thuật gợi ý bài hát cho người dùng:
#
# <figure>
#     <img src="./Chart_1.png" style="width:60%;height:60%;">
#     <figcaption>Framework cho chương trình đề xuất nhạc</figcaption>
# </figure>
#
# <figure>
#     <img src="./Chart_2.png" style="width:60%;height:60%;">
#     <figcaption>Framework cho chương trình đề xuất nhạc</figcaption>
# </figure>
#
# #### 2.2. Các bước tiến hành
# - **Bước 1: Thu thập dữ liệu:**
#     - Điều này bao gồm thông tin về bài hát được nghe, thời gian nghe, thể loại nhạc, và các thao tác tương tác khác trên nền tảng.
#     - Dữ liệu này được sử dụng để hiểu sở thích và yêu cầu âm nhạc của mỗi người dùng.
# - **Bước 2: Phân tích dữ liệu:**
#     - Phân tích dữ liệu để hiểu sở thích của người dùng. Điều này có thể bao gồm phân tích thể loại nhạc, phát hiện xu hướng, và xác định các yếu tố quan trọng khác như nghệ sĩ, album, và tỷ lệ lắng nghe.
#     - Sự tương tác của người dùng với các bài hát khác nhau, bao gồm việc thích, bỏ qua, lưu vào thư viện, v.v.
# - **Bước 3: Xây dựng mô hình:**
#     - Xây dựng/sử dụng mô hình học máy để dự đoán sở thích âm nhạc của người dùng.
#     - Mô hình này được huấn luyện trên dữ liệu lịch sử phát nhạc của người dùng để tạo ra các đề xuất phát nhạc cá nhân hóa.
# - **Bước 4: Tích hợp vào ứng dụng:**
#     - Tích hợp trực tiếp vào ứng dụng như Spotify, nơi người dùng có thể truy cập và nghe từ trang cá nhân của họ.
#     - Các bài hát được đề xuất dựa trên mô hình cá nhân hóa và được cập nhật mỗi tuần.
# - **Bước 5: Đánh giá và tinh chỉnh:**
#     - Đánh giá hiệu suất của thông qua phản hồi từ người dùng và các phương tiện đo lường khác như tỷ lệ nghe, thời lượng nghe, v.v.
#     - Dựa trên thông tin này để tinh chỉnh mô hình, cải thiện chất lượng của các đề xuất phát nhạc.
#
# ### 3. Mô tả nghiệp vụ
# - Dựa trên yêu cầu này, ta có thể phân chia thành 3 nhóm nghiệp vụ cơ bản:
#
#     - **Bước 1. Thu thập và xử lý dữ liệu người dùng và bài hát**
#     - **Bước 2. Phát triển và huấn luyện mô hình trí tuệ nhân tạo**
#     - **Bước 3. Cá nhân hóa và đề xuất danh sách phát**

# %% [markdown]
# ## III. Phương pháp giải quyết bài toán
#
# ### 1. Các mô hinh Machine learning
# Những chương trình gợi ý bài hát, thành công nhất là Spotify Discover Weekly lựa chọn việc kết hợp một cách hiệu quả các thuật toán đã có, trong đó có 3 kiểu mô hình gợi ý như:
#
# - Mô hình Lọc cộng tác (Collaborative Filtering): Từng được áp dụng trong tiện ích gợi ý nhạc của Last.fm, gợi ý phát của Netflix, các mô hình theo phương pháp này sẽ phân tích các hành vi của người dùng cũng như hành vi của mọi người khác thông qua các phản hồi ngầm. Cụ thể, trình phát theo dõi các bài hát mà ta nghe, việc ta truy cập vào trang của nghệ sĩ sau khi nghe bài hát, thêm bài hát vào playlist.
#
#     - Để thực hiện được trong chương trình thì Spotify phải dùng đến các ma trận toán học, được hỗ trợ với các thư viện Python.
#
# <figure>
#     <img src="./Chart_2.png" style="width:60%;height:60%;">
#     <figcaption>Ma trận hai chiều sử dụng trong thuật toán</figcaption>
# </figure>
#
# - Trên thực tế, ma trận trận là một ma trận khổng lồ với khoảng 140 triệu hàng tương đương với 140 triệu người dùng của spotify, và mỗi cột trong ma trận này là một trong khoảng 30 triệu bài hát đang có trong cơ sở dữ liệu. Việc đã nghe một bài hát sẽ tương đương với giá trị 1 trong ma trận, sau đó thư viện python sẽ chạy các hàm toán học để tính toán, trả về các vectơ X đại diện cho sở thích của người dùng và vectơ Y đại diện cho đặc điểm các bài hát. Thuật toán tiếp theo sẽ so sánh vectơ của từng người dùng với nhau bằng cách nhân tích vô hướng và tích nào có kết quả bé nhất sẽ tương đương với các người dùng có cùng sở thích, cũng như với các vectơ Y thì thuật toán sẽ so sánh độ giống nhau giữa các bài hát để trả về bài hát người dùng tìm kiếm.
#
# <figure>
#     <img src="./Chart_3.png" style="width:60%;height:60%;">
#     <figcaption>Công thức phân tích ma trận thành nhân tử</figcaption>
# </figure>
#
# -> Công thức trên cho phép phân tích ma trận lớn Users/Songs trên thành 2 ma trận low-rank X và Y
#
# - Mô hình xử lý ngôn ngữ tự nhiên (NLP): Sử dụng Collaborative Filtering là hiệu quả và cho phép đưa ra các kết quả tốt, nhưng chương trình còn có thể tốt hơn với việc áp dụng các mô hình NLP vào để làm cho máy hiểu được ngôn ngữ nói của con người. Cụ thể, Spotify liên tục crawl các dữ liệu từ trên nền tảng web, các bài blog hay báo về âm nhạc, tìm hiểu xem mọi người có những suy nghĩ gì về từng nghệ sĩ và bài hát cụ thể, một thuật ngữ được spotify sử dụng trong mô hình này là “cultural vectors” hay “top terms” tức chỉ những thuật ngữ cho thấy mô tả những đặc điểm của nghệ sĩ và bài hát được thay đổi qua từng ngày.
#
# <figure>
#     <img src="./Chart_4.png" style="width:60%;height:60%;">
#     <figcaption>Một ví dụ về các thuật ngữ và trọng số đánh giá của các thuật ngữ đó đối với máy tính</figcaption>
# </figure>
#
#
# - Mô hình NLP sử dụng các thuật ngữ và trọng số này để tạo vectơ thể hiện bài hát cho máy tính hiểu từ đó đánh giá xem hai bài có giống nhau hay không.
#
# - Mô hình âm thanh: Mô hình này cho phép tăng độ chính xác của chương trình, đồng thời nó đưa ra giải pháp cho vấn đề của 2 mô hình trên là cho phép giới thiệu các bài hát mới tới người dùng. Ví dụ, một bài hát mới được đẩy lên Spotify, có thể là từ một nhạc sĩ/ca sĩ chưa có tên tuổi nên lượt nghe của nó chỉ là 50 lượt, vậy làm sao để mô hình lọc cộng tác và NLP có thể đánh giá nếu giá trị tích vô hướng của 2 vectơ Users và Songs là không chính xác cũng như không có bài viết nào cho NLP xử lý.
#
#     - Raw audio model thì lại không phân biệt bài hát cũ và mới, vậy nên những bài hát dù mới và ít người nghe vẫn có thể được thêm vào khi giới thiệu. Mô hình này sử dụng các mạng lưới thần kinh tích chập, thay vì các pixels ảnh như trong nhận diện khuôn mặt thì mô hình này sử dụng âm thanh, thể hiện qua ví dụ dưới đây:
#
# <figure>
#     <img src="./Chart_5.png" style="width:60%;height:60%;">
# </figure>
#
# - Mạng lưới thần kinh đặc biệt này có bốn lớp tích chập, được coi là các thanh dày ở bên trái và ba lớp dày đặc, được coi là các thanh hẹp hơn ở bên phải. Đầu vào là các biểu diễn tần số thời gian của các khung âm thanh, sau đó được ghép nối để tạo thành biểu đồ phổ.
#
#     - Các khung âm thanh đi qua các lớp tích chập này và sau lớp tích chập cuối cùng, ta có thể thấy một lớp “global temporal pooling”, bao gồm toàn bộ trục thời gian, tính toán số liệu thống kê một cách hiệu quả về các đặc điểm đã học trong suốt thời gian của bài hát.
#
#     - Tất cả thông tin này sau đó sẽ đến lớp đầu ra, lớp này dự đoán sự hiểu biết về đặc điểm của bài hát: Nó có nhịp độ cao không? Nó có phải là âm thanh không? Nó có khả năng khiêu vũ cao không? Tất cả những đặc điểm này có thể được tìm thấy với độ chính xác khá cao chỉ bằng cách sử dụng mạng nơ ron trên các tệp âm thanh thuần.
#
# ### 2. Lọc cộng tác (Collaborative Filtering)
# Lọc cộng tác dựa vào ý tưởng rằng những người dùng có sở thích tương tự sẽ thích những sản phẩm tương tự. Trong trường hợp này, sản phẩm là các bài hát. Để áp dụng mô hình này vào bài toán:
#
# - **Thu thập dữ liệu:** Dữ liệu người dùng và tương tác của họ với các bài hát (lượt nghe, thêm vào playlist, vv.).
# - **Xây dựng Ma trận Tương tác:** Sử dụng ma trận người dùng-bài hát, trong đó mỗi hàng đại diện cho một người dùng và mỗi cột đại diện cho một bài hát. Giá trị trong ma trận thể hiện sự tương tác của người dùng với bài hát.
# - **Phân tích Ma trận:** Áp dụng các kỹ thuật như Phân tích Ma trận Nhân tử để xác định các mối quan hệ ẩn giữa người dùng và bài hát.
# - **Đề xuất:** Dựa trên mô hình đã huấn luyện, dự đoán và đề xuất các bài hát mới mà người dùng có khả năng thích.
#
# ### 3. Xử lý ngôn ngữ tự nhiên (NLP)
# NLP cho phép máy tính hiểu được ngôn ngữ tự nhiên của con người. Áp dụng NLP vào bài toán này giúp cải thiện khả năng đề xuất bằng cách phân tích ngữ cảnh và ý nghĩa của lời bài hát hoặc các bài viết, nhận xét về nghệ sĩ và bài hát:
#
# - **Thu thập dữ liệu văn bản:** Bao gồm lời bài hát, bài đánh giá, blog âm nhạc, vv.
# - **Xử lý và Phân tích Dữ liệu Văn bản:** Sử dụng các mô hình NLP để xác định các "cultural vectors" hoặc "top terms" mô tả đặc điểm của nghệ sĩ và bài hát.
# - **Tích hợp vào Đề xuất:** Dùng dữ liệu từ NLP để bổ sung vào mô hình đề xuất, giúp tăng độ chính xác bằng cách thêm ngữ cảnh và ý nghĩa văn hóa vào quyết định.
#
# ### 4. Mô hình âm thanh
# Mô hình này trực tiếp phân tích âm thanh của bài hát để tìm ra các đặc điểm như nhịp độ, giai điệu, âm sắc, vv. Cách áp dụng:
#
# - **Phân tích Âm thanh:** Sử dụng mạng lưới thần kinh tích chập để phân tích tín hiệu âm thanh, trích xuất các đặc điểm quan trọng.
# - **Huấn luyện Mô hình:** Huấn luyện mô hình với dữ liệu âm thanh để nhận biết các đặc điểm của bài hát.
# - **Đề xuất Dựa trên Âm thanh:** Sử dụng đầu ra của mô hình để đề xuất các bài hát với đặc điểm âm thanh tương tự, kể cả với các bài hát mới chưa có dữ liệu tương tác người dùng.
#
# ##### **Tổng hợp 3 Mô hình**
#
# Kết hợp ba mô hình trên vào một hệ thống tổng hợp để tận dụng ưu điểm của từng mô hình, tăng cường độ chính xác và đa dạng của các đề xuất. Hệ thống tổng hợp này sẽ:
#
# - **Phân tích Tương tác Người dùng:** Để hiểu sở thích và hành vi.
# - **Phân tích Nội dung:** Dựa vào văn bản và ngữ cảnh văn hóa.
# - **Phân tích Âm thanh:** Để khám phá đặc điểm âm nhạc của bài hát.
#
# Sự kết hợp này giúp tạo ra một hệ thống đề xuất vững chắc, cá nhân hóa, và linh hoạt, có khả năng đề xuất các bài hát chính xác theo sở thích cá nhân của từng người dùng.
#
# ### 5. Áp dụng lọc cộng tác
# **Bước Để Áp Dụng Lọc Cộng Tác:**
#
# 1. Thu thập dữ liệu người dùng:
#
# - Dữ liệu về tương tác người dùng với bài hát, bao gồm lượt nghe, lượt thích, lượt bỏ qua, thêm vào danh sách phát, v.v.
#
# 2. Xây dựng ma trận tương tác người dùng-bài hát:
#
# - Một ma trận hai chiều, với mỗi hàng đại diện cho một người dùng và mỗi cột đại diện cho một bài hát. Các giá trị trong ma trận này phản ánh mức độ tương tác của người dùng với từng bài hát.
#
# 3. Sử dụng một thư viện Python đơn giản:
#
# - Có nhiều thư viện Python hỗ trợ Lọc cộng tác, như **`scikit-learn`**, **`Surprise`**, hoặc **`LightFM`**.
# - Ví dụ, sử dụng thư viện **`Surprise`** để xây dựng và đánh giá mô hình lọc cộng tác có thể được thực hiện với ít dòng code.
#
# 4. Huấn luyện mô hình:
#
# - Sử dụng dữ liệu đã thu thập để huấn luyện mô hình. Trong quá trình này, mô hình sẽ học cách dự đoán sở thích của người dùng dựa trên sở thích của người dùng khác.
#
# 5. Đề xuất bài hát:
#
# - Sau khi mô hình đã được huấn luyện, bạn có thể sử dụng nó để đề xuất bài hát cho người dùng dựa trên sở thích tương tự của các người dùng khác.

# %% [markdown]
# ## IV. Kết quả
# - Website BeatFit
# <figure>
#     <img src="./fe1.png" style="width:60%;height:60%;">
#     <figcaption>Giao diện trang chủ</figcaption>
# </figure>
#
# <figure>
#     <img src="./fe2.png" style="width:60%;height:60%;">
#     <figcaption>Hiển thị danh sách các bài hát</figcaption>
# </figure>
#
# <figure>
#     <img src="./fe3.png" style="width:60%;height:60%;">
#     <figcaption>Áp dụng lọc cộng tác để list ra các bài hát theo gợi ý</figcaption>
# </figure>
#
# <figure>
#     <img src="./fe4.png" style="width:60%;height:60%;">
#     <figcaption>Tìm kiếm các danh mục/ bài hát</figcaption>
# </figure>

# %% [markdown]
# ## V. Khó khăn cần khắc phục
#
# - Khó khăn khi làm việc với hai mô hình Collaborative filtering và mô hình âm thanh:
#     - Đối với Collaborative filtering, việc chuyển các bài hát từ dạng audio sang data yêu cầu một bước preprocessing, tức xử lý với các biên độ, tần số, … (Deep learning)
#     - Đối với mô hình âm thanh, yêu cầu kiến thức về kỹ thuật truyền thông khá cao
